# %%
#live_test
from live_bci import *

# %%
pure_tone = [np.sin(2*np.pi*14.6*t) for t in np.arange(0,5,1/250)]

# %%
import matplotlib.pyplot as plt
plt.plot(pure_tone)

# %%
samp_list = [[pure_tone[i]]*8 for i in range(len(pure_tone))]

# %%
pred = classify_freq(samp_list,False)

# %%
pred
# Out:
# 14.8

# %%
if pred - 10 < 1e-3:
    print('yay')
