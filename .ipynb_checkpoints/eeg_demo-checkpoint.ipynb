# %%
from preprocessing import *
from import_data import *
data_dir = 'DataCollection/outputs/'
ssvep_dir = data_dir + 'SSVEP/sess1'
mi_dir = data_dir + 'MI/sess1'
bci_dir = '../Documents/OpenBCI_GUI/Recordings/OpenBCISession_2023-02-28_12-03-49/'
col_names = ['Fp1', 'O1', 'O2','C3','C4','P3','P4','Pz']

# %%
ssvep_files = get_files(ssvep_dir)
ssvep_files = [ssvep_files[i] for i in range(len(ssvep_files)) if (i+1)%11!=0]
mi_files = get_files(mi_dir)
mi_files = [mi_files[i] for i in range(len(mi_files)) if (i+1)%6!=0]
bci_files = get_files(bci_dir)

# %%
for i, fi in enumerate(ssvep_files):
    print("{}: {}\n".format(i,fi))
# Out:
# 0: DataCollection/outputs/SSVEP/2023-02-28T12:35:26.048567_10.000000000000002Hz.txt
#
# 1: DataCollection/outputs/SSVEP/2023-02-28T12:35:26.048567_10.800000000000002Hz.txt
#
# 2: DataCollection/outputs/SSVEP/2023-02-28T12:35:26.048567_11.600000000000003Hz.txt
#
# 3: DataCollection/outputs/SSVEP/2023-02-28T12:35:26.048567_12.400000000000004Hz.txt
#
# 4: DataCollection/outputs/SSVEP/2023-02-28T12:35:26.048567_13.200000000000005Hz.txt
#
# 5: DataCollection/outputs/SSVEP/2023-02-28T12:35:26.048567_14.000000000000005Hz.txt
#
# 6: DataCollection/outputs/SSVEP/2023-02-28T12:35:26.048567_14.800000000000006Hz.txt
#
# 7: DataCollection/outputs/SSVEP/2023-02-28T12:35:26.048567_15.600000000000007Hz.txt
#
# 8: DataCollection/outputs/SSVEP/2023-02-28T12:35:26.048567_8.4Hz.txt
#
# 9: DataCollection/outputs/SSVEP/2023-02-28T12:35:26.048567_9.200000000000001Hz.txt
#
# 10: DataCollection/outputs/SSVEP/2023-02-28T12:42:06.599375_10.000000000000002Hz.txt
#
# 11: DataCollection/outputs/SSVEP/2023-02-28T12:42:06.599375_10.800000000000002Hz.txt
#
# 12: DataCollection/outputs/SSVEP/2023-02-28T12:42:06.599375_11.600000000000003Hz.txt
#
# 13: DataCollection/outputs/SSVEP/2023-02-28T12:42:06.599375_12.400000000000004Hz.txt
#
# 14: DataCollection/outputs/SSVEP/2023-02-28T12:42:06.599375_13.200000000000005Hz.txt
#
# 15: DataCollection/outputs/SSVEP/2023-02-28T12:42:06.599375_14.000000000000005Hz.txt
#
# 16: DataCollection/outputs/SSVEP/2023-02-28T12:42:06.599375_14.800000000000006Hz.txt
#
# 17: DataCollection/outputs/SSVEP/2023-02-28T12:42:06.599375_15.600000000000007Hz.txt
#
# 18: DataCollection/outputs/SSVEP/2023-02-28T12:42:06.599375_8.4Hz.txt
#
# 19: DataCollection/outputs/SSVEP/2023-02-28T12:42:06.599375_9.200000000000001Hz.txt
#
# 20: DataCollection/outputs/SSVEP/2023-02-28T12:44:33.661549_10.000000000000002Hz.txt
#
# 21: DataCollection/outputs/SSVEP/2023-02-28T12:44:33.661549_10.800000000000002Hz.txt
#
# 22: DataCollection/outputs/SSVEP/2023-02-28T12:44:33.661549_11.600000000000003Hz.txt
#
# 23: DataCollection/outputs/SSVEP/2023-02-28T12:44:33.661549_12.400000000000004Hz.txt
#
# 24: DataCollection/outputs/SSVEP/2023-02-28T12:44:33.661549_13.200000000000005Hz.txt
#
# 25: DataCollection/outputs/SSVEP/2023-02-28T12:44:33.661549_14.000000000000005Hz.txt
#
# 26: DataCollection/outputs/SSVEP/2023-02-28T12:44:33.661549_14.800000000000006Hz.txt
#
# 27: DataCollection/outputs/SSVEP/2023-02-28T12:44:33.661549_15.600000000000007Hz.txt
#
# 28: DataCollection/outputs/SSVEP/2023-02-28T12:44:33.661549_8.4Hz.txt
#
# 29: DataCollection/outputs/SSVEP/2023-02-28T12:44:33.661549_9.200000000000001Hz.txt
#
# 30: DataCollection/outputs/SSVEP/2023-02-28T12:46:45.850187_10.000000000000002Hz.txt
#
# 31: DataCollection/outputs/SSVEP/2023-02-28T12:46:45.850187_10.800000000000002Hz.txt
#
# 32: DataCollection/outputs/SSVEP/2023-02-28T12:46:45.850187_11.600000000000003Hz.txt
#
# 33: DataCollection/outputs/SSVEP/2023-02-28T12:46:45.850187_12.400000000000004Hz.txt
#
# 34: DataCollection/outputs/SSVEP/2023-02-28T12:46:45.850187_13.200000000000005Hz.txt
#
# 35: DataCollection/outputs/SSVEP/2023-02-28T12:46:45.850187_14.000000000000005Hz.txt
#
# 36: DataCollection/outputs/SSVEP/2023-02-28T12:46:45.850187_14.800000000000006Hz.txt
#
# 37: DataCollection/outputs/SSVEP/2023-02-28T12:46:45.850187_15.600000000000007Hz.txt
#
# 38: DataCollection/outputs/SSVEP/2023-02-28T12:46:45.850187_8.4Hz.txt
#
# 39: DataCollection/outputs/SSVEP/2023-02-28T12:46:45.850187_9.200000000000001Hz.txt

# %%
eeg, Fs = process_eeg(ssvep_files[0], col_names, bci_files[8], low=2.0)

# %%
def plot_ssvep(eeg):
    for chan in eeg.columns:
            plt.figure()
            #plt.xlim(4,5)
            plot_channel(eeg, chan, Fs)

# %%
plot_ssvep(eeg)

# %%
def plot_mi(eeg):
    for chan in eeg.columns:
        for i in range(4):
            plt.figure()
            plt.xlim(i*5+0.5,(i+1)*5-0.5)
            plot_channel(eeg, chan, Fs, start=i*5, end=(i+1)*5)

# %%
eeg, Fs = process_eeg(mi_files[3], col_names, bci_files[7], low=2)

# %%
eeg_np = eeg.to_numpy()
eeg_np.shape
# Out:
# (3500, 8)

# %%
train_data = np.array([eeg_np[i*1250:(i+1)*1250].reshape(8,1250) for i in range(4)])
train_data.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/r5/gg5z6rvn6bb70r67y0ntjw8w0000gn/T/ipykernel_30774/4200764845.py in <module>
# ----> 1 train_data = np.array([eeg_np[i*1250:(i+1)*1250].reshape(8,1250) for i in range(4)])
#       2 train_data.shape
#
# /var/folders/r5/gg5z6rvn6bb70r67y0ntjw8w0000gn/T/ipykernel_30774/4200764845.py in <listcomp>(.0)
# ----> 1 train_data = np.array([eeg_np[i*1250:(i+1)*1250].reshape(8,1250) for i in range(4)])
#       2 train_data.shape
#
# ValueError: cannot reshape array of size 8000 into shape (8,1250)

# %%
plot_mi(eeg)

# %%
'''
for i,fi in enumerate(ssvep_files):
    if ((i+1)%11==0):
        continue
    eeg = process_eeg(fi, col_names, bci_files[9])
    print(eeg)
'''

# %%
freqs, ps = power_spectrum(eeg, 250)

# %%
plot_power(freqs, ps, 'Fp1', 250, 50)
