# %%
from preprocessing import *
from import_data import *
from sklearn.decomposition import FastICA
data_dir = 'DataCollection/outputs/'
ssvep_dir = data_dir + 'SSVEP/sess1/'
mi_dir = data_dir + 'MI/sess1/'
bci_dir = '../Documents/OpenBCI_GUI/Recordings/OpenBCISession_2023-02-28_12-03-49/'
col_names = ['Fp1', 'O1', 'O2','C3','C4','P3','P4','Pz']
ssvep_files = get_files(ssvep_dir)
ssvep_files = [ssvep_files[i] for i in range(len(ssvep_files)) if (i+1)%11!=0]
mi_files = get_files(mi_dir)
mi_files = [mi_files[i] for i in range(len(mi_files)) if (i+1)%6!=0]
bci_files = get_files(bci_dir)

# %%
eeg, Fs = process_eeg(ssvep_files[0], col_names, bci_files[8], low=1.0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/r5/gg5z6rvn6bb70r67y0ntjw8w0000gn/T/ipykernel_30843/3622074298.py in <module>
# ----> 1 eeg, Fs = process_eeg(ssvep_files[0], col_names, bci_files[8], low=1.0)
#
# ~/Spelling-BeeCI/preprocessing.py in process_eeg(eeg_file, col_names, openbci_file, low, high)
#     113
#     114 def process_eeg(eeg_file, col_names, openbci_file, low=1, high=50):
# --> 115     eeg = read_file(eeg_file, col_names)
#     116     openbci, num_channels, Fs, column_names = read_openbci_file(openbci_file)
#     117     idx = get_idx(openbci, column_names, eeg, col_names)
#
# ~/Spelling-BeeCI/import_data.py in read_file(file_name, col_names)
#      10
#      11 def read_file(file_name, col_names):
# ---> 12     eeg = pd.read_csv(file_name,header=None)
#      13     eeg.columns = col_names
#      14     return eeg
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     603
#     604     # Create the parser.
# --> 605     parser = TextFileReader(filepath_or_buffer, **kwds)
#     606
#     607     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1440
#    1441         self.handles: IOHandles | None = None
# -> 1442         self._engine = self._make_engine(f, self.engine)
#    1443
#    1444     def close(self) -> None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1733                 if "b" not in mode:
#    1734                     mode += "b"
# -> 1735             self.handles = get_handle(
#    1736                 f,
#    1737                 mode,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854         if ioargs.encoding and "b" not in ioargs.mode:
#     855             # Encoding
# --> 856             handle = open(
#     857                 handle,
#     858                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'DataCollection/outputs/SSVEP/sess12023-02-27T12:18:36.792539_metadata.txt'

# %%
eeg.shape
# Out:
# (1000, 8)

# %%
def svt(data, threshold):
    min_ = np.min(data) <= -1*threshold
    #max_ = np.max(data) >= threshold
    return min_ #or max_

# %%
data = np.arange(-50,80,1)
print(svt(data,60))
# Out:
# False

# %%
data = svt(eeg['Fp1'], 230)

# %%
data
# Out:
# False

# %%
eeg, Fs = process_eeg(ssvep_files[1], col_names, bci_files[8], low=1.0)

# %%
ica = FastICA(n_components=8, max_iter=1000, tol=0.01, whiten='unit-variance')
eeg_np = eeg.to_numpy()
ica.fit(eeg_np)
# Out:
# FastICA(max_iter=1000, n_components=8, tol=0.01, whiten='unit-variance')

# %%
eeg_np.shape
# Out:
# (1000, 8)

# %%
'''
import matplotlib.pyplot as plt

for i in range(8):
    plt.psd(ica.components_[i], Fs=Fs)
    plt.title('Component {}'.format(i))
    plt.show()
'''
# Out:
# "\nimport matplotlib.pyplot as plt\n\nfor i in range(8):\n    plt.psd(ica.components_[i], Fs=Fs)\n    plt.title('Component {}'.format(i))\n    plt.show()\n"

# %%
blink_idx = [7]  #3
S = ica.transform(eeg_np)
S[:, blink_idx] = 0
eeg_filtered = ica.inverse_transform(S)

# %%
plt.plot(eeg_np[:,0])
plt.figure()
plt.plot(eeg_filtered[:,0]);
#plt.xlim(0,20)

# %%
def remove_eye_blinks(eeg):
    ica = FastICA(n_components=8, max_iter=1000, tol=0.01, whiten='unit-variance')
    eeg_np = eeg.to_numpy()
    ica.fit(eeg_np)
    S = ica.transform(eeg_np)
    for i in range(8):
        temp = S[:, i]
        S[:, i] = 0
        eeg_filtered = ica.inverse_transform(S)
        if svt(eeg_filtered[0], 100)==False:
            print('Success')
            return eeg_filtered
        print('Trying again')
        S[:, i] = temp
    return eeg

# %%
eeg, Fs = process_eeg(ssvep_files[1], col_names, bci_files[8], low=1.0)

# %%
filtered_eeg = remove_eye_blinks(eeg)
# Out:
# Success

# %%
eeg, Fs = process_eeg(ssvep_files[0], col_names, bci_files[8], low=2.0)
filtered_eeg = remove_eye_blinks(eeg)
plt.plot(eeg['Fp1']);
plt.title('Unfiltered Fp1');
plt.figure()
plt.plot(filtered_eeg[:,0]);
plt.title('Filtered Fp1');
# Out:
# Success

# %%
freq = 10.000200
print("{:.2f}".format(freq))
# Out:
# 10.00
