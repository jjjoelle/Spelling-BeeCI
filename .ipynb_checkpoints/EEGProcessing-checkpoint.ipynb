# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
data_dir = 'DataCollection/outputs/'
ssvep_dir = data_dir + 'SSVEP/'
mi_dir = data_dir + 'MI/'

# %%
ssvep_files = []
for file in sorted(os.listdir(ssvep_dir)):
    ssvep_files.append(ssvep_dir + file)
mi_files = []
for file in sorted(os.listdir(mi_dir)):
    ssvep_files.append(mi_dir + file)

# %%
df = pd.read_csv(ssvep_files[0],header=None)
col_names = ['Fp1', 'O1', 'O2','C3','C4','P3','P4','Pz']
df.columns = col_names

# %%
df
# Out:
#               Fp1           O1           O2         C3           C4  \
# 0     1908.369629 -7540.941895 -5446.695312 -52.191322 -5635.791016
# 1     1986.868896 -7533.186035 -5567.752441 -47.318642 -5646.140137
# 2     2066.061035 -7705.674316 -5730.338867 -49.754982 -5730.897949
# 3     2014.875610 -7731.334473 -5623.408203 -54.135925 -5734.764648
# 4     1947.082764 -7566.557129 -5444.058105 -48.078602 -5648.799805
# ...           ...          ...          ...        ...          ...
# 1245  2058.729736 -7568.054688 -5536.482422 -61.512001 -5647.347168
# 1246  2148.293213 -7672.750488 -5740.464355 -61.176723 -5709.216797
# 1247  2164.341797 -7812.672363 -5795.226074 -68.776321 -5773.231934
# 1248  2090.692871 -7723.779297 -5608.343262 -69.446869 -5716.615234
# 1249  2070.106934 -7557.817871 -5516.120117 -59.969730 -5642.474609
#
#                P3           P4            Pz
# 0    -4516.482910  4036.859131  10212.154297
# 1    -4493.729004  4140.571289  10205.605469
# 2    -4490.912598  4230.246582  10156.700195
# 3    -4513.912598  4137.352539  10159.739258
# 4    -4517.868652  4038.066162  10208.064453
# ...           ...          ...           ...
# 1245 -4535.928711  4028.924316  10162.130859
# 1246 -4519.030762  4162.028809  10122.724609
# 1247 -4531.726562  4162.833496  10090.114258
# 1248 -4547.082520  4042.447021  10124.333984
# 1249 -4532.956055  4018.150635  10164.634766
#
# [1250 rows x 8 columns]

# %%
def getFileData(fileName):
    df = pd.read_csv(fileName,header=None)
    df.columns = col_names
    return df
def plotChannel(df, channel):
    chan_data = list(df[channel])
    times = np.arange(len(chan_data))*dt
    plt.plot(times, chan_data)

# %%
Fs = 250
dt = 1/Fs
times = np.arange(1250)*dt
chan_data = list(df['O1'])
plt.plot(times, chan_data);
plt.xlim(2,2.25)
# Out:
# (2.0, 2.25)

# %%
df10 = getFileData(ssvep_files[0])
plotChannel(df10, 'Pz')

# %%
chan_data = list(df['O1'])
ps = np.fft.fft(chan_data)
freqs = np.fft.fftfreq(n=len(chan_data), d=dt)
plt.plot(freqs,ps)
#plt.xlim(-5,5)
